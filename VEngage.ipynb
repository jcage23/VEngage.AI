# %% [markdown]
# Problem 1

# %% [markdown]
# The task is to read phone book records from CSV or JSON file

# %%
#Here we are using the Pandas for reading the CSV File

# %%
#We will import the Pandas library and using the read_csv() function we can read the CSV file into Pandas DataFrame

# %%
import pandas as pd
phone_records = pd.read_csv('Phone_records.csv')
print(phone_records)
# Out:
#         Name            Email      Phone 1     Phone 2
# 0        John     John@xyz.com  1234567890  9098765432
# 1       Lukas    Lukas@xyz.com  1122334455  5544332211
# 2     Sheldon  Sheldon@xyz.com  1111122222  2222211111
# 3     Leonard  Leonard@xyz.com  2222233333  3333322222
# 4      Howard   Howard@xyz.com  3333344444  4444433333
# 5      Rajesh   Rajesh@xyz.com  4444455555  5555544444
# 6       Penny    Penny@xyz.com  5555566666  6666655555
# 7  Bernadette  Bdetter@xyz.com  6666677777  7777766666
# 8         Doe      Doe@xyz.com  7777788888  8888877777
# 9      Stuart   Stuart@xyz.com  8888899999  9999988888

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# Problem 2

# %% [markdown]
# Implement a SQL-like parser for phone book records to implement CRUD
# operations

# %% [markdown]
# 2.1

# %%
#2.1
#Displaying the first few records from the Phonebook Records

# %%
phone_records.head()
#By default the head() returns the first five records from the table. We can specify the no of records to be displayed by mentioning the count inside the head().
# Out:
#      Name            Email      Phone 1     Phone 2
# 0     John     John@xyz.com  1234567890  9098765432
# 1    Lukas    Lukas@xyz.com  1122334455  5544332211
# 2  Sheldon  Sheldon@xyz.com  1111122222  2222211111
# 3  Leonard  Leonard@xyz.com  2222233333  3333322222
# 4   Howard   Howard@xyz.com  3333344444  4444433333

# %% [markdown]
# 2.2

# %%
#2.2
#this statement filters the records and displays where the name is 'Doe'

# %%
#We are performing the selection of the record with name 'Doe' in pandas
select = phone_records.loc[phone_records['Name '] == 'Doe']
select
# Out:
#   Name        Email      Phone 1     Phone 2
# 8   Doe  Doe@xyz.com  7777788888  8888877777

# %% [markdown]
# 2.3

# %%
#2.3
#This statement should create a new entry in the dataset

# %%
#We are performing simple insertion into the phonerecords using pandas
new_record = ['Amy','Amy@xyz.com',1111111111,2222222222]
phone_records.loc[len(phone_records)] = new_record

# %%
#Displaying the current records in the phonerecords. The new record can be seen inserted into the table
phone_records
# Out:
#          Name            Email      Phone 1     Phone 2
# 0         John     John@xyz.com  1234567890  9098765432
# 1        Lukas    Lukas@xyz.com  1122334455  5544332211
# 2      Sheldon  Sheldon@xyz.com  1111122222  2222211111
# 3      Leonard  Leonard@xyz.com  2222233333  3333322222
# 4       Howard   Howard@xyz.com  3333344444  4444433333
# 5       Rajesh   Rajesh@xyz.com  4444455555  5555544444
# 6        Penny    Penny@xyz.com  5555566666  6666655555
# 7   Bernadette  Bdetter@xyz.com  6666677777  7777766666
# 8          Doe      Doe@xyz.com  7777788888  8888877777
# 9       Stuart   Stuart@xyz.com  8888899999  9999988888
# 10         Amy      Amy@xyz.com  1111111111  2222222222

# %% [markdown]
# 2.4

# %%
#2.4
#This statement should delete the record from the dataset.

# %%
phone_records.drop(phone_records.loc[phone_records['Name '] == 'John'].index,inplace= True)
phone_records
#We could see the record corresponding to John as been deleted from the table
# Out:
#          Name            Email      Phone 1     Phone 2
# 1        Lukas    Lukas@xyz.com  1122334455  5544332211
# 2      Sheldon  Sheldon@xyz.com  1111122222  2222211111
# 3      Leonard  Leonard@xyz.com  2222233333  3333322222
# 4       Howard   Howard@xyz.com  3333344444  4444433333
# 5       Rajesh   Rajesh@xyz.com  4444455555  5555544444
# 6        Penny    Penny@xyz.com  5555566666  6666655555
# 7   Bernadette  Bdetter@xyz.com  6666677777  7777766666
# 8          Doe      Doe@xyz.com  7777788888  8888877777
# 9       Stuart   Stuart@xyz.com  8888899999  9999988888
# 10         Amy      Amy@xyz.com  1111111111  2222222222

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# The basic CRUD operations have been performed using the Pandas here
